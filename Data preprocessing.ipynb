# %%
# Importing the required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import sigmoid_kernel, linear_kernel, cosine_similarity

# %%
data1 = pd.read_csv('Engineering books data/agri_data.csv')
data2 = pd.read_csv('Engineering books data/bio_data.csv')
data3 = pd.read_csv('Engineering books data/civil_data.csv')
data4 = pd.read_csv('Engineering books data/cse_data.csv')
data5 = pd.read_csv('Engineering books data/ec_data.csv')
data6 = pd.read_csv('Engineering books data/eee_data.csv')
data7 = pd.read_csv('Engineering books data/it_data.csv')
data8 = pd.read_csv('Engineering books data/mech_data.csv')
data9 = pd.read_csv('Engineering books data/robotic_data.csv')
data10 = pd.read_csv('Engineering books data/additional_data.csv')

# %%
df = [data1, data2, data3, data4, data5, data6, data7, data8, data9, data10]
data = pd.concat(df)
data = data.reset_index(drop=True)

# %%
data.shape
# Out:
# (2375, 10)

# %%
data
# Out:
#                                                   title  \
# 0     Soil Mechanics of Earthworks, Foundations and ...
# 1     Foundation Engineering: Design and Constructio...
# 2     Practical Problems in Soil Mechanics and Found...
# 3     Underwater Embankments on Soft Soil A Case His...
# 4     Eco- and Ground Bio-Engineering: The Use of Ve...
# ...                                                 ...
# 2370  Search Engines: Information Retrieval in Practice
# 2371                          Web Information Retrieval
# 2372                       Modern Information Retrieval
# 2373  Information Access through Search Engines and ...
# 2374  Issues in the Use of Neural Networks in Inform...
#
#                           author  \
# 0                            NaN
# 1                    B.B.K. Huat
# 2                  Sheng Y. Peng
# 3            William F. van Impe
# 4                  Alexia Stokes
# ...                          ...
# 2370              W. Bruce Croft
# 2371                Stefano Ceri
# 2372         Ricardo Baeza-Yates
# 2373  Maristella Agosti (Editor)
# 2374    Iuliana F. Iatan (auth.)
#
#                                                   image  \
# 0     https://covers.zlibcdn2.com/covers100/books/01...
# 1     https://covers.zlibcdn2.com/covers100/books/1b...
# 2     https://covers.zlibcdn2.com/covers100/books/7d...
# 3     https://covers.zlibcdn2.com/covers100/books/2b...
# 4     https://covers.zlibcdn2.com/covers100/books/d2...
# ...                                                 ...
# 2370  https://covers.zlibcdn2.com/covers100/books/01...
# 2371  https://covers.zlibcdn2.com/covers100/books/8e...
# 2372  https://covers.zlibcdn2.com/covers100/books/7f...
# 2373  https://covers.zlibcdn2.com/covers100/books/a7...
# 2374  https://covers.zlibcdn2.com/covers100/books/82...
#
#                                                    desc  \
# 0     \n                    This is the third volume...
# 1     \n                    Residual soils are found...
# 2                                               Unknown
# 3                                               Unknown
# 4     \n                    This volume brings toget...
# ...                                                 ...
# 2370                                            Unknown
# 2371  \nWith the proliferation of huge amounts of (h...
# 2372  \n                    Discusses the changes in...
# 2373  \n                    The Information Manageme...
# 2374  \nThis book highlights the ability of neural n...
#
#                           download_link pages  \
# 0     https://1lib.in/dl/2279969/9cd462   354
# 1     https://1lib.in/dl/1247565/f9e712   256
# 2     https://1lib.in/dl/2800423/3ccf77   346
# 3      https://1lib.in/dl/981008/e79e1d   154
# 4      https://1lib.in/dl/901430/e57c96   420
# ...                                 ...   ...
# 2370  https://1lib.in/dl/5148053/69b42b   542
# 2371  https://1lib.in/dl/2167059/097330   284
# 2372   https://1lib.in/dl/605897/eb0156   103
# 2373   https://1lib.in/dl/937104/93711b   214
# 2374  https://1lib.in/dl/2837743/71e6de   213
#
#                               publisher  year language           file
# 0                      Elsevier Science  1988  english   PDF, 9.35 MB
# 1                      Taylor & Francis  2006  english  PDF, 86.52 MB
# 2                  Elsevier Science Ltd  1985  english   PDF, 9.86 MB
# 3                               Unknown  2007  english   PDF, 3.35 MB
# 4                               Unknown  2007  english  PDF, 10.67 MB
# ...                                 ...   ...      ...            ...
# 2370                            Pearson  2009  english   PDF, 9.11 MB
# 2371  Springer-Verlag Berlin Heidelberg  2013  english   PDF, 7.44 MB
# 2372          ACM Press; Addison-Wesley  1999  english   PDF, 1.95 MB
# 2373                            Unknown  2007  english   PDF, 3.67 MB
# 2374  Springer International Publishing  2017  english   PDF, 7.38 MB
#
# [2375 rows x 10 columns]

# %%
data.isnull().sum()
# Out:
# title             0
# author           22
# image             3
# desc              0
# download_link     0
# pages             0
# publisher         0
# year              0
# language          0
# file              0
# dtype: int64

# %%
data = data.dropna()
data = data.reset_index(drop=True)

# %%
data.isnull().sum()
# Out:
# title            0
# author           0
# image            0
# desc             0
# download_link    0
# pages            0
# publisher        0
# year             0
# language         0
# file             0
# dtype: int64

# %%
data = data[data['desc'] !='Unknown']
data = data.reset_index(drop=True)
data.shape
# Out:
# (1744, 10)

# %%
data = data[data['download_link'] != 'Unknown']
data = data.reset_index(drop=True)
data.shape
# Out:
# (1736, 10)

# %%
unknown_author = data[data['author'] == 'Unknown']
unknown_desc = data[data['desc'] == 'Unknown']
unknown_download_link = data[data['download_link'] == 'Unknown']
unknown_pages = data[data['pages'] == 'Unknown']
unknown_publisher = data[data['publisher'] == 'Unknown']
unknown_year = data[data['year'] == 'Unknown']
unknown_language = data[data['language'] == 'Unknown']
unknown_file = data[data['file'] == 'Unknown']
unknown_img = data[data['image'] == 'Unknown']

# %%
print('unknown authors:', len(unknown_author))
print('unknown desc:',len(unknown_desc))
print('unknown download link:', len(unknown_download_link))
print('unknown pages:', len(unknown_pages))
print('unknown publisher:', len(unknown_publisher))
print('unknown year:', len(unknown_year))
print('unknown language:', len(unknown_language))
print('unknown file:', len(unknown_file))
print('unknown image:', len(unknown_img))
# Out:
# unknown authors: 0
# unknown desc: 0
# unknown download link: 0
# unknown pages: 205
# unknown publisher: 134
# unknown year: 46
# unknown language: 2
# unknown file: 0
# unknown image: 0

# %%
data['lower title'] = data['title'].str.lower()

# %%
data
# Out:
#                                                   title  \
# 0     Foundation Engineering: Design and Constructio...
# 1     Eco- and Ground Bio-Engineering: The Use of Ve...
# 2     Education and Training in Geo-Engineering Scie...
# 3     Soil and Water Contamination: From molecular t...
# 4                          Principles of Thermodynamics
# ...                                                 ...
# 1731  Quantum-Like Models for Information Retrieval ...
# 1732                          Web Information Retrieval
# 1733                       Modern Information Retrieval
# 1734  Information Access through Search Engines and ...
# 1735  Issues in the Use of Neural Networks in Inform...
#
#                           author  \
# 0                    B.B.K. Huat
# 1                  Alexia Stokes
# 2        Iacint Manoliu (Editor)
# 3            Marcel van der Perk
# 4         Jean-Philippe Ansermet
# ...                          ...
# 1731              Diederik Aerts
# 1732                Stefano Ceri
# 1733         Ricardo Baeza-Yates
# 1734  Maristella Agosti (Editor)
# 1735    Iuliana F. Iatan (auth.)
#
#                                                   image  \
# 0     https://covers.zlibcdn2.com/covers100/books/1b...
# 1     https://covers.zlibcdn2.com/covers100/books/d2...
# 2     https://covers.zlibcdn2.com/covers100/books/2a...
# 3     https://covers.zlibcdn2.com/covers100/books/3e...
# 4     https://covers.zlibcdn2.com/covers100/books/29...
# ...                                                 ...
# 1731  https://covers.zlibcdn2.com/covers100/books/85...
# 1732  https://covers.zlibcdn2.com/covers100/books/8e...
# 1733  https://covers.zlibcdn2.com/covers100/books/7f...
# 1734  https://covers.zlibcdn2.com/covers100/books/a7...
# 1735  https://covers.zlibcdn2.com/covers100/books/82...
#
#                                                    desc  \
# 0     \n                    Residual soils are found...
# 1     \n                    This volume brings toget...
# 2     \nIn recent years the International Society fo...
# 3     \n                    This textbook provides a...
# 4     \n                    In this introductory tex...
# ...                                                 ...
# 1731  \nRecent years have been characterized by trem...
# 1732  \nWith the proliferation of huge amounts of (h...
# 1733  \n                    Discusses the changes in...
# 1734  \n                    The Information Manageme...
# 1735  \nThis book highlights the ability of neural n...
#
#                           download_link    pages  \
# 0     https://1lib.in/dl/1247565/f9e712      256
# 1      https://1lib.in/dl/901430/e57c96      420
# 2     https://1lib.in/dl/5982938/e28e87  Unknown
# 3      https://1lib.in/dl/966945/b3831a      404
# 4     https://1lib.in/dl/3685253/9f5b4e      529
# ...                                 ...      ...
# 1731  https://1lib.in/dl/5399359/157c21  Unknown
# 1732  https://1lib.in/dl/2167059/097330      284
# 1733   https://1lib.in/dl/605897/eb0156      103
# 1734   https://1lib.in/dl/937104/93711b      214
# 1735  https://1lib.in/dl/2837743/71e6de      213
#
#                               publisher  year language            file  \
# 0                      Taylor & Francis  2006  english   PDF, 86.52 MB
# 1                               Unknown  2007  english   PDF, 10.67 MB
# 2                             CRC Press  2008  Unknown  PDF, 375.03 MB
# 3                               Unknown  2006  english    PDF, 5.78 MB
# 4            Cambridge University Press  2019  english   PDF, 11.50 MB
# ...                                 ...   ...      ...             ...
# 1731  Springer International Publishing  2019  english    PDF, 2.87 MB
# 1732  Springer-Verlag Berlin Heidelberg  2013  english    PDF, 7.44 MB
# 1733          ACM Press; Addison-Wesley  1999  english    PDF, 1.95 MB
# 1734                            Unknown  2007  english    PDF, 3.67 MB
# 1735  Springer International Publishing  2017  english    PDF, 7.38 MB
#
#                                             lower title
# 0     foundation engineering: design and constructio...
# 1     eco- and ground bio-engineering: the use of ve...
# 2     education and training in geo-engineering scie...
# 3     soil and water contamination: from molecular t...
# 4                          principles of thermodynamics
# ...                                                 ...
# 1731  quantum-like models for information retrieval ...
# 1732                          web information retrieval
# 1733                       modern information retrieval
# 1734  information access through search engines and ...
# 1735  issues in the use of neural networks in inform...
#
# [1736 rows x 11 columns]

# %%
data = data.drop_duplicates(subset=['lower title'])
data = data.reset_index(drop=True)
data.shape
# Out:
# (1461, 11)

# %%
data['title length'] = ''
def title_length(column):
    for i in range(column.shape[0]):
        length = len(column[i])
        data['title length'][i] = length

# %%
title_length(data['title'])

# %%
data.head()
# Out:
#                                                title                   author  \
# 0  Foundation Engineering: Design and Constructio...              B.B.K. Huat
# 1  Eco- and Ground Bio-Engineering: The Use of Ve...            Alexia Stokes
# 2  Education and Training in Geo-Engineering Scie...  Iacint Manoliu (Editor)
# 3  Soil and Water Contamination: From molecular t...      Marcel van der Perk
# 4                       Principles of Thermodynamics   Jean-Philippe Ansermet
#
#                                                image  \
# 0  https://covers.zlibcdn2.com/covers100/books/1b...
# 1  https://covers.zlibcdn2.com/covers100/books/d2...
# 2  https://covers.zlibcdn2.com/covers100/books/2a...
# 3  https://covers.zlibcdn2.com/covers100/books/3e...
# 4  https://covers.zlibcdn2.com/covers100/books/29...
#
#                                                 desc  \
# 0  \n                    Residual soils are found...
# 1  \n                    This volume brings toget...
# 2  \nIn recent years the International Society fo...
# 3  \n                    This textbook provides a...
# 4  \n                    In this introductory tex...
#
#                        download_link    pages                   publisher  \
# 0  https://1lib.in/dl/1247565/f9e712      256            Taylor & Francis
# 1   https://1lib.in/dl/901430/e57c96      420                     Unknown
# 2  https://1lib.in/dl/5982938/e28e87  Unknown                   CRC Press
# 3   https://1lib.in/dl/966945/b3831a      404                     Unknown
# 4  https://1lib.in/dl/3685253/9f5b4e      529  Cambridge University Press
#
#    year language            file  \
# 0  2006  english   PDF, 86.52 MB
# 1  2007  english   PDF, 10.67 MB
# 2  2008  Unknown  PDF, 375.03 MB
# 3  2006  english    PDF, 5.78 MB
# 4  2019  english   PDF, 11.50 MB
#
#                                          lower title title length
# 0  foundation engineering: design and constructio...          144
# 1  eco- and ground bio-engineering: the use of ve...          197
# 2  education and training in geo-engineering scie...          132
# 3  soil and water contamination: from molecular t...          142
# 4                       principles of thermodynamics           28

# %%
sns.distplot(data['title length'])
# Out:
# C:\Users\ELCOT\Anaconda3\envs\finalproject\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='title length', ylabel='Density'>

# %%
data = data[data['title length'] < 180]
data = data.reset_index(drop=True)

# %%
sns.distplot(data['title length'])
# Out:
# C:\Users\ELCOT\Anaconda3\envs\finalproject\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='title length', ylabel='Density'>

# %%
data.shape
# Out:
# (1447, 12)

# %%
data.head()
# Out:
#                                                title                   author  \
# 0  Foundation Engineering: Design and Constructio...              B.B.K. Huat
# 1  Education and Training in Geo-Engineering Scie...  Iacint Manoliu (Editor)
# 2  Soil and Water Contamination: From molecular t...      Marcel van der Perk
# 3                       Principles of Thermodynamics   Jean-Philippe Ansermet
# 4  Thermodynamics: An Engineering Approach 8th Ed...          Yunus A. Çengel
#
#                                                image  \
# 0  https://covers.zlibcdn2.com/covers100/books/1b...
# 1  https://covers.zlibcdn2.com/covers100/books/2a...
# 2  https://covers.zlibcdn2.com/covers100/books/3e...
# 3  https://covers.zlibcdn2.com/covers100/books/29...
# 4  https://covers.zlibcdn2.com/covers100/books/6a...
#
#                                                 desc  \
# 0  \n                    Residual soils are found...
# 1  \nIn recent years the International Society fo...
# 2  \n                    This textbook provides a...
# 3  \n                    In this introductory tex...
# 4  \nThermodynamics, An Engineering Approach, eig...
#
#                        download_link    pages                   publisher  \
# 0  https://1lib.in/dl/1247565/f9e712      256            Taylor & Francis
# 1  https://1lib.in/dl/5982938/e28e87  Unknown                   CRC Press
# 2   https://1lib.in/dl/966945/b3831a      404                     Unknown
# 3  https://1lib.in/dl/3685253/9f5b4e      529  Cambridge University Press
# 4  https://1lib.in/dl/2577672/7b237e     1115       McGraw-Hill Education
#
#    year language            file  \
# 0  2006  english   PDF, 86.52 MB
# 1  2008  Unknown  PDF, 375.03 MB
# 2  2006  english    PDF, 5.78 MB
# 3  2019  english   PDF, 11.50 MB
# 4  2014  english   PDF, 64.77 MB
#
#                                          lower title title length
# 0  foundation engineering: design and constructio...          144
# 1  education and training in geo-engineering scie...          132
# 2  soil and water contamination: from molecular t...          142
# 3                       principles of thermodynamics           28
# 4  thermodynamics: an engineering approach 8th ed...           51

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ELCOT\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def cleaning(message):
    text = [char for char in message if char not in string.punctuation]
    text = ''.join(text)
    text = [word for word in text.split() if word.lower() not in stopwords.words('english')]
    text = ' '.join(text)
    return text

# %%
clean_data = data.title.apply(cleaning)

# %%
clean_data
# Out:
# 0       Foundation Engineering Design Construction Tro...
# 1       Education Training GeoEngineering Sciences Soi...
# 2       Soil Water Contamination molecular catchment s...
# 3                               Principles Thermodynamics
# 4         Thermodynamics Engineering Approach 8th Edition
#                               ...
# 1442    Textual Visual Information Retrieval using Que...
# 1443    QuantumLike Models Information Retrieval Decis...
# 1444                            Web Information Retrieval
# 1445    Information Access Search Engines Digital Libr...
# 1446     Issues Use Neural Networks Information Retrieval
# Name: title, Length: 1447, dtype: object

# %%
data.title
# Out:
# 0       Foundation Engineering: Design and Constructio...
# 1       Education and Training in Geo-Engineering Scie...
# 2       Soil and Water Contamination: From molecular t...
# 3                            Principles of Thermodynamics
# 4       Thermodynamics: An Engineering Approach 8th Ed...
#                               ...
# 1442    Textual and Visual Information Retrieval using...
# 1443    Quantum-Like Models for Information Retrieval ...
# 1444                            Web Information Retrieval
# 1445    Information Access through Search Engines and ...
# 1446    Issues in the Use of Neural Networks in Inform...
# Name: title, Length: 1447, dtype: object

# %%
data['recommend char'] = clean_data

# %%
data.head()
# Out:
#                                                title                   author  \
# 0  Foundation Engineering: Design and Constructio...              B.B.K. Huat
# 1  Education and Training in Geo-Engineering Scie...  Iacint Manoliu (Editor)
# 2  Soil and Water Contamination: From molecular t...      Marcel van der Perk
# 3                       Principles of Thermodynamics   Jean-Philippe Ansermet
# 4  Thermodynamics: An Engineering Approach 8th Ed...          Yunus A. Çengel
#
#                                                image  \
# 0  https://covers.zlibcdn2.com/covers100/books/1b...
# 1  https://covers.zlibcdn2.com/covers100/books/2a...
# 2  https://covers.zlibcdn2.com/covers100/books/3e...
# 3  https://covers.zlibcdn2.com/covers100/books/29...
# 4  https://covers.zlibcdn2.com/covers100/books/6a...
#
#                                                 desc  \
# 0  \n                    Residual soils are found...
# 1  \nIn recent years the International Society fo...
# 2  \n                    This textbook provides a...
# 3  \n                    In this introductory tex...
# 4  \nThermodynamics, An Engineering Approach, eig...
#
#                        download_link    pages                   publisher  \
# 0  https://1lib.in/dl/1247565/f9e712      256            Taylor & Francis
# 1  https://1lib.in/dl/5982938/e28e87  Unknown                   CRC Press
# 2   https://1lib.in/dl/966945/b3831a      404                     Unknown
# 3  https://1lib.in/dl/3685253/9f5b4e      529  Cambridge University Press
# 4  https://1lib.in/dl/2577672/7b237e     1115       McGraw-Hill Education
#
#    year language            file  \
# 0  2006  english   PDF, 86.52 MB
# 1  2008  Unknown  PDF, 375.03 MB
# 2  2006  english    PDF, 5.78 MB
# 3  2019  english   PDF, 11.50 MB
# 4  2014  english   PDF, 64.77 MB
#
#                                          lower title title length  \
# 0  foundation engineering: design and constructio...          144
# 1  education and training in geo-engineering scie...          132
# 2  soil and water contamination: from molecular t...          142
# 3                       principles of thermodynamics           28
# 4  thermodynamics: an engineering approach 8th ed...           51
#
#                                       recommend char
# 0  Foundation Engineering Design Construction Tro...
# 1  Education Training GeoEngineering Sciences Soi...
# 2  Soil Water Contamination molecular catchment s...
# 3                          Principles Thermodynamics
# 4    Thermodynamics Engineering Approach 8th Edition

# %%
# data['large image'] = ''
data['large image'] = data['image']
for i in range(data.shape[0]):
    data['large image'][i] = data['large image'][i].replace('covers100', 'covers300')

# %%
data
# Out:
#                                                   title  \
# 0     Foundation Engineering: Design and Constructio...
# 1     Education and Training in Geo-Engineering Scie...
# 2     Soil and Water Contamination: From molecular t...
# 3                          Principles of Thermodynamics
# 4     Thermodynamics: An Engineering Approach 8th Ed...
# ...                                                 ...
# 1442  Textual and Visual Information Retrieval using...
# 1443  Quantum-Like Models for Information Retrieval ...
# 1444                          Web Information Retrieval
# 1445  Information Access through Search Engines and ...
# 1446  Issues in the Use of Neural Networks in Inform...
#
#                           author  \
# 0                    B.B.K. Huat
# 1        Iacint Manoliu (Editor)
# 2            Marcel van der Perk
# 3         Jean-Philippe Ansermet
# 4                Yunus A. Çengel
# ...                          ...
# 1442                 S.G. Shaila
# 1443              Diederik Aerts
# 1444                Stefano Ceri
# 1445  Maristella Agosti (Editor)
# 1446    Iuliana F. Iatan (auth.)
#
#                                                   image  \
# 0     https://covers.zlibcdn2.com/covers100/books/1b...
# 1     https://covers.zlibcdn2.com/covers100/books/2a...
# 2     https://covers.zlibcdn2.com/covers100/books/3e...
# 3     https://covers.zlibcdn2.com/covers100/books/29...
# 4     https://covers.zlibcdn2.com/covers100/books/6a...
# ...                                                 ...
# 1442  https://covers.zlibcdn2.com/covers100/books/fc...
# 1443  https://covers.zlibcdn2.com/covers100/books/85...
# 1444  https://covers.zlibcdn2.com/covers100/books/8e...
# 1445  https://covers.zlibcdn2.com/covers100/books/a7...
# 1446  https://covers.zlibcdn2.com/covers100/books/82...
#
#                                                    desc  \
# 0     \n                    Residual soils are found...
# 1     \nIn recent years the International Society fo...
# 2     \n                    This textbook provides a...
# 3     \n                    In this introductory tex...
# 4     \nThermodynamics, An Engineering Approach, eig...
# ...                                                 ...
# 1442  \nThis book offers comprehensive coverage of i...
# 1443  \nRecent years have been characterized by trem...
# 1444  \nWith the proliferation of huge amounts of (h...
# 1445  \n                    The Information Manageme...
# 1446  \nThis book highlights the ability of neural n...
#
#                           download_link    pages  \
# 0     https://1lib.in/dl/1247565/f9e712      256
# 1     https://1lib.in/dl/5982938/e28e87  Unknown
# 2      https://1lib.in/dl/966945/b3831a      404
# 3     https://1lib.in/dl/3685253/9f5b4e      529
# 4     https://1lib.in/dl/2577672/7b237e     1115
# ...                                 ...      ...
# 1442  https://1lib.in/dl/3664508/888c47  Unknown
# 1443  https://1lib.in/dl/5399359/157c21  Unknown
# 1444  https://1lib.in/dl/2167059/097330      284
# 1445   https://1lib.in/dl/937104/93711b      214
# 1446  https://1lib.in/dl/2837743/71e6de      213
#
#                               publisher  year language            file  \
# 0                      Taylor & Francis  2006  english   PDF, 86.52 MB
# 1                             CRC Press  2008  Unknown  PDF, 375.03 MB
# 2                               Unknown  2006  english    PDF, 5.78 MB
# 3            Cambridge University Press  2019  english   PDF, 11.50 MB
# 4                 McGraw-Hill Education  2014  english   PDF, 64.77 MB
# ...                                 ...   ...      ...             ...
# 1442                 Springer Singapore  2018  english    PDF, 6.78 MB
# 1443  Springer International Publishing  2019  english    PDF, 2.87 MB
# 1444  Springer-Verlag Berlin Heidelberg  2013  english    PDF, 7.44 MB
# 1445                            Unknown  2007  english    PDF, 3.67 MB
# 1446  Springer International Publishing  2017  english    PDF, 7.38 MB
#
#                                             lower title title length  \
# 0     foundation engineering: design and constructio...          144
# 1     education and training in geo-engineering scie...          132
# 2     soil and water contamination: from molecular t...          142
# 3                          principles of thermodynamics           28
# 4     thermodynamics: an engineering approach 8th ed...           51
# ...                                                 ...          ...
# 1442  textual and visual information retrieval using...           84
# 1443  quantum-like models for information retrieval ...           65
# 1444                          web information retrieval           25
# 1445  information access through search engines and ...           98
# 1446  issues in the use of neural networks in inform...           61
#
#                                          recommend char  \
# 0     Foundation Engineering Design Construction Tro...
# 1     Education Training GeoEngineering Sciences Soi...
# 2     Soil Water Contamination molecular catchment s...
# 3                             Principles Thermodynamics
# 4       Thermodynamics Engineering Approach 8th Edition
# ...                                                 ...
# 1442  Textual Visual Information Retrieval using Que...
# 1443  QuantumLike Models Information Retrieval Decis...
# 1444                          Web Information Retrieval
# 1445  Information Access Search Engines Digital Libr...
# 1446   Issues Use Neural Networks Information Retrieval
#
#                                             large image
# 0     https://covers.zlibcdn2.com/covers300/books/1b...
# 1     https://covers.zlibcdn2.com/covers300/books/2a...
# 2     https://covers.zlibcdn2.com/covers300/books/3e...
# 3     https://covers.zlibcdn2.com/covers300/books/29...
# 4     https://covers.zlibcdn2.com/covers300/books/6a...
# ...                                                 ...
# 1442  https://covers.zlibcdn2.com/covers300/books/fc...
# 1443  https://covers.zlibcdn2.com/covers300/books/85...
# 1444  https://covers.zlibcdn2.com/covers300/books/8e...
# 1445  https://covers.zlibcdn2.com/covers300/books/a7...
# 1446  https://covers.zlibcdn2.com/covers300/books/82...
#
# [1447 rows x 14 columns]

# %%
data['medium image'] = data['image']
for i in range(data.shape[0]):
    data['medium image'][i] = data['medium image'][i].replace('covers100', 'covers200')

# %%
data
# Out:
#                                                   title  \
# 0     Foundation Engineering: Design and Constructio...
# 1     Education and Training in Geo-Engineering Scie...
# 2     Soil and Water Contamination: From molecular t...
# 3                          Principles of Thermodynamics
# 4     Thermodynamics: An Engineering Approach 8th Ed...
# ...                                                 ...
# 1442  Textual and Visual Information Retrieval using...
# 1443  Quantum-Like Models for Information Retrieval ...
# 1444                          Web Information Retrieval
# 1445  Information Access through Search Engines and ...
# 1446  Issues in the Use of Neural Networks in Inform...
#
#                           author  \
# 0                    B.B.K. Huat
# 1        Iacint Manoliu (Editor)
# 2            Marcel van der Perk
# 3         Jean-Philippe Ansermet
# 4                Yunus A. Çengel
# ...                          ...
# 1442                 S.G. Shaila
# 1443              Diederik Aerts
# 1444                Stefano Ceri
# 1445  Maristella Agosti (Editor)
# 1446    Iuliana F. Iatan (auth.)
#
#                                                   image  \
# 0     https://covers.zlibcdn2.com/covers100/books/1b...
# 1     https://covers.zlibcdn2.com/covers100/books/2a...
# 2     https://covers.zlibcdn2.com/covers100/books/3e...
# 3     https://covers.zlibcdn2.com/covers100/books/29...
# 4     https://covers.zlibcdn2.com/covers100/books/6a...
# ...                                                 ...
# 1442  https://covers.zlibcdn2.com/covers100/books/fc...
# 1443  https://covers.zlibcdn2.com/covers100/books/85...
# 1444  https://covers.zlibcdn2.com/covers100/books/8e...
# 1445  https://covers.zlibcdn2.com/covers100/books/a7...
# 1446  https://covers.zlibcdn2.com/covers100/books/82...
#
#                                                    desc  \
# 0     \n                    Residual soils are found...
# 1     \nIn recent years the International Society fo...
# 2     \n                    This textbook provides a...
# 3     \n                    In this introductory tex...
# 4     \nThermodynamics, An Engineering Approach, eig...
# ...                                                 ...
# 1442  \nThis book offers comprehensive coverage of i...
# 1443  \nRecent years have been characterized by trem...
# 1444  \nWith the proliferation of huge amounts of (h...
# 1445  \n                    The Information Manageme...
# 1446  \nThis book highlights the ability of neural n...
#
#                           download_link    pages  \
# 0     https://1lib.in/dl/1247565/f9e712      256
# 1     https://1lib.in/dl/5982938/e28e87  Unknown
# 2      https://1lib.in/dl/966945/b3831a      404
# 3     https://1lib.in/dl/3685253/9f5b4e      529
# 4     https://1lib.in/dl/2577672/7b237e     1115
# ...                                 ...      ...
# 1442  https://1lib.in/dl/3664508/888c47  Unknown
# 1443  https://1lib.in/dl/5399359/157c21  Unknown
# 1444  https://1lib.in/dl/2167059/097330      284
# 1445   https://1lib.in/dl/937104/93711b      214
# 1446  https://1lib.in/dl/2837743/71e6de      213
#
#                               publisher  year language            file  \
# 0                      Taylor & Francis  2006  english   PDF, 86.52 MB
# 1                             CRC Press  2008  Unknown  PDF, 375.03 MB
# 2                               Unknown  2006  english    PDF, 5.78 MB
# 3            Cambridge University Press  2019  english   PDF, 11.50 MB
# 4                 McGraw-Hill Education  2014  english   PDF, 64.77 MB
# ...                                 ...   ...      ...             ...
# 1442                 Springer Singapore  2018  english    PDF, 6.78 MB
# 1443  Springer International Publishing  2019  english    PDF, 2.87 MB
# 1444  Springer-Verlag Berlin Heidelberg  2013  english    PDF, 7.44 MB
# 1445                            Unknown  2007  english    PDF, 3.67 MB
# 1446  Springer International Publishing  2017  english    PDF, 7.38 MB
#
#                                             lower title title length  \
# 0     foundation engineering: design and constructio...          144
# 1     education and training in geo-engineering scie...          132
# 2     soil and water contamination: from molecular t...          142
# 3                          principles of thermodynamics           28
# 4     thermodynamics: an engineering approach 8th ed...           51
# ...                                                 ...          ...
# 1442  textual and visual information retrieval using...           84
# 1443  quantum-like models for information retrieval ...           65
# 1444                          web information retrieval           25
# 1445  information access through search engines and ...           98
# 1446  issues in the use of neural networks in inform...           61
#
#                                          recommend char  \
# 0     Foundation Engineering Design Construction Tro...
# 1     Education Training GeoEngineering Sciences Soi...
# 2     Soil Water Contamination molecular catchment s...
# 3                             Principles Thermodynamics
# 4       Thermodynamics Engineering Approach 8th Edition
# ...                                                 ...
# 1442  Textual Visual Information Retrieval using Que...
# 1443  QuantumLike Models Information Retrieval Decis...
# 1444                          Web Information Retrieval
# 1445  Information Access Search Engines Digital Libr...
# 1446   Issues Use Neural Networks Information Retrieval
#
#                                             large image  \
# 0     https://covers.zlibcdn2.com/covers300/books/1b...
# 1     https://covers.zlibcdn2.com/covers300/books/2a...
# 2     https://covers.zlibcdn2.com/covers300/books/3e...
# 3     https://covers.zlibcdn2.com/covers300/books/29...
# 4     https://covers.zlibcdn2.com/covers300/books/6a...
# ...                                                 ...
# 1442  https://covers.zlibcdn2.com/covers300/books/fc...
# 1443  https://covers.zlibcdn2.com/covers300/books/85...
# 1444  https://covers.zlibcdn2.com/covers300/books/8e...
# 1445  https://covers.zlibcdn2.com/covers300/books/a7...
# 1446  https://covers.zlibcdn2.com/covers300/books/82...
#
#                                            medium image
# 0     https://covers.zlibcdn2.com/covers200/books/1b...
# 1     https://covers.zlibcdn2.com/covers200/books/2a...
# 2     https://covers.zlibcdn2.com/covers200/books/3e...
# 3     https://covers.zlibcdn2.com/covers200/books/29...
# 4     https://covers.zlibcdn2.com/covers200/books/6a...
# ...                                                 ...
# 1442  https://covers.zlibcdn2.com/covers200/books/fc...
# 1443  https://covers.zlibcdn2.com/covers200/books/85...
# 1444  https://covers.zlibcdn2.com/covers200/books/8e...
# 1445  https://covers.zlibcdn2.com/covers200/books/a7...
# 1446  https://covers.zlibcdn2.com/covers200/books/82...
#
# [1447 rows x 15 columns]

# %%
data['clean desc'] = ''
for i in range(data.shape[0]):
    splited = data['desc'][i].split()
    clean_data = ' '.join(splited)
    data['clean desc'][i] = clean_data

# %%
data['clean desc'][0][:250]
# Out:
# 'Residual soils are found in many parts of the world. Like other soils, they are used extensively in construction, being built upon and used as construction materials. Residual soils are formed when the processes of rock weathering proceed at a faster'

# %%
data
# Out:
#                                                   title  \
# 0     Foundation Engineering: Design and Constructio...
# 1     Education and Training in Geo-Engineering Scie...
# 2     Soil and Water Contamination: From molecular t...
# 3                          Principles of Thermodynamics
# 4     Thermodynamics: An Engineering Approach 8th Ed...
# ...                                                 ...
# 1442  Textual and Visual Information Retrieval using...
# 1443  Quantum-Like Models for Information Retrieval ...
# 1444                          Web Information Retrieval
# 1445  Information Access through Search Engines and ...
# 1446  Issues in the Use of Neural Networks in Inform...
#
#                           author  \
# 0                    B.B.K. Huat
# 1        Iacint Manoliu (Editor)
# 2            Marcel van der Perk
# 3         Jean-Philippe Ansermet
# 4                Yunus A. Çengel
# ...                          ...
# 1442                 S.G. Shaila
# 1443              Diederik Aerts
# 1444                Stefano Ceri
# 1445  Maristella Agosti (Editor)
# 1446    Iuliana F. Iatan (auth.)
#
#                                                   image  \
# 0     https://covers.zlibcdn2.com/covers100/books/1b...
# 1     https://covers.zlibcdn2.com/covers100/books/2a...
# 2     https://covers.zlibcdn2.com/covers100/books/3e...
# 3     https://covers.zlibcdn2.com/covers100/books/29...
# 4     https://covers.zlibcdn2.com/covers100/books/6a...
# ...                                                 ...
# 1442  https://covers.zlibcdn2.com/covers100/books/fc...
# 1443  https://covers.zlibcdn2.com/covers100/books/85...
# 1444  https://covers.zlibcdn2.com/covers100/books/8e...
# 1445  https://covers.zlibcdn2.com/covers100/books/a7...
# 1446  https://covers.zlibcdn2.com/covers100/books/82...
#
#                                                    desc  \
# 0     \n                    Residual soils are found...
# 1     \nIn recent years the International Society fo...
# 2     \n                    This textbook provides a...
# 3     \n                    In this introductory tex...
# 4     \nThermodynamics, An Engineering Approach, eig...
# ...                                                 ...
# 1442  \nThis book offers comprehensive coverage of i...
# 1443  \nRecent years have been characterized by trem...
# 1444  \nWith the proliferation of huge amounts of (h...
# 1445  \n                    The Information Manageme...
# 1446  \nThis book highlights the ability of neural n...
#
#                           download_link    pages  \
# 0     https://1lib.in/dl/1247565/f9e712      256
# 1     https://1lib.in/dl/5982938/e28e87  Unknown
# 2      https://1lib.in/dl/966945/b3831a      404
# 3     https://1lib.in/dl/3685253/9f5b4e      529
# 4     https://1lib.in/dl/2577672/7b237e     1115
# ...                                 ...      ...
# 1442  https://1lib.in/dl/3664508/888c47  Unknown
# 1443  https://1lib.in/dl/5399359/157c21  Unknown
# 1444  https://1lib.in/dl/2167059/097330      284
# 1445   https://1lib.in/dl/937104/93711b      214
# 1446  https://1lib.in/dl/2837743/71e6de      213
#
#                               publisher  year language            file  \
# 0                      Taylor & Francis  2006  english   PDF, 86.52 MB
# 1                             CRC Press  2008  Unknown  PDF, 375.03 MB
# 2                               Unknown  2006  english    PDF, 5.78 MB
# 3            Cambridge University Press  2019  english   PDF, 11.50 MB
# 4                 McGraw-Hill Education  2014  english   PDF, 64.77 MB
# ...                                 ...   ...      ...             ...
# 1442                 Springer Singapore  2018  english    PDF, 6.78 MB
# 1443  Springer International Publishing  2019  english    PDF, 2.87 MB
# 1444  Springer-Verlag Berlin Heidelberg  2013  english    PDF, 7.44 MB
# 1445                            Unknown  2007  english    PDF, 3.67 MB
# 1446  Springer International Publishing  2017  english    PDF, 7.38 MB
#
#                                             lower title title length  \
# 0     foundation engineering: design and constructio...          144
# 1     education and training in geo-engineering scie...          132
# 2     soil and water contamination: from molecular t...          142
# 3                          principles of thermodynamics           28
# 4     thermodynamics: an engineering approach 8th ed...           51
# ...                                                 ...          ...
# 1442  textual and visual information retrieval using...           84
# 1443  quantum-like models for information retrieval ...           65
# 1444                          web information retrieval           25
# 1445  information access through search engines and ...           98
# 1446  issues in the use of neural networks in inform...           61
#
#                                          recommend char  \
# 0     Foundation Engineering Design Construction Tro...
# 1     Education Training GeoEngineering Sciences Soi...
# 2     Soil Water Contamination molecular catchment s...
# 3                             Principles Thermodynamics
# 4       Thermodynamics Engineering Approach 8th Edition
# ...                                                 ...
# 1442  Textual Visual Information Retrieval using Que...
# 1443  QuantumLike Models Information Retrieval Decis...
# 1444                          Web Information Retrieval
# 1445  Information Access Search Engines Digital Libr...
# 1446   Issues Use Neural Networks Information Retrieval
#
#                                             large image  \
# 0     https://covers.zlibcdn2.com/covers300/books/1b...
# 1     https://covers.zlibcdn2.com/covers300/books/2a...
# 2     https://covers.zlibcdn2.com/covers300/books/3e...
# 3     https://covers.zlibcdn2.com/covers300/books/29...
# 4     https://covers.zlibcdn2.com/covers300/books/6a...
# ...                                                 ...
# 1442  https://covers.zlibcdn2.com/covers300/books/fc...
# 1443  https://covers.zlibcdn2.com/covers300/books/85...
# 1444  https://covers.zlibcdn2.com/covers300/books/8e...
# 1445  https://covers.zlibcdn2.com/covers300/books/a7...
# 1446  https://covers.zlibcdn2.com/covers300/books/82...
#
#                                            medium image  \
# 0     https://covers.zlibcdn2.com/covers200/books/1b...
# 1     https://covers.zlibcdn2.com/covers200/books/2a...
# 2     https://covers.zlibcdn2.com/covers200/books/3e...
# 3     https://covers.zlibcdn2.com/covers200/books/29...
# 4     https://covers.zlibcdn2.com/covers200/books/6a...
# ...                                                 ...
# 1442  https://covers.zlibcdn2.com/covers200/books/fc...
# 1443  https://covers.zlibcdn2.com/covers200/books/85...
# 1444  https://covers.zlibcdn2.com/covers200/books/8e...
# 1445  https://covers.zlibcdn2.com/covers200/books/a7...
# 1446  https://covers.zlibcdn2.com/covers200/books/82...
#
#                                              clean desc
# 0     Residual soils are found in many parts of the ...
# 1     In recent years the International Society for ...
# 2     This textbook provides an overview of transpor...
# 3     In this introductory textbook, thermodynamics ...
# 4     Thermodynamics, An Engineering Approach, eight...
# ...                                                 ...
# 1442  This book offers comprehensive coverage of inf...
# 1443  Recent years have been characterized by tremen...
# 1444  With the proliferation of huge amounts of (het...
# 1445  The Information Management Systems group at th...
# 1446  This book highlights the ability of neural net...
#
# [1447 rows x 16 columns]

# %%
data.to_csv('engineering_data.csv', index=False)
